# %%
import pandas as pd
from matplotlib import pyplot as plt
data=pd.read_csv('train.csv')

# %%
data.astype(str)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#
# KeyboardInterrupt

# %%
var=[]
for i in range(200):
    v='var_'+str(i)
    var.append(v)

# %%
col=['var_1','var_2']
col
# Out:
# ['var_1', 'var_2']

# %%
data['combine'] =data[col].apply(lambda x: ''.join(x), axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-5125445c543e> in <module>
# ----> 1 data['combine'] =data[col].apply(lambda x: ''.join(x), axis=0)
#
# c:\program files\python36\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# c:\program files\python36\lib\site-packages\pandas\core\apply.py in get_result(self)
#     316                                       *self.args, **self.kwds)
#     317
# --> 318         return super(FrameRowApply, self).get_result()
#     319
#     320     def apply_broadcast(self):
#
# c:\program files\python36\lib\site-packages\pandas\core\apply.py in get_result(self)
# ...

# %%
data1.shape
# Out:
# (7826, 2)

# %%
data.to_csv('final.csv',index=False)

# %%
pd.options.display.max_columns = None
data.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %%
data.head(5)
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7   var_8   var_9  var_10   var_11   var_12   var_13  var_14  \
# 0  18.6266 -4.9200  5.7470  2.9252   3.1821  14.0137   0.5745  8.7989
# 1  16.5338  3.1468  8.0851 -0.4032   8.0585  14.0239   8.4135  5.4345
# 2  14.6155 -4.9193  5.9525 -0.3249 -11.2648  14.1929   7.3124  7.5244
# 3  14.9250 -5.8609  8.2450  2.3061   2.8102  13.8463  11.9704  6.4569
# 4  19.2514  6.2654  7.6784 -9.4458 -12.1419  13.8481   7.8895  7.7894
#
# ...

# %%
'''data.loc[data.var_6 > data.var_6.median() ,'var_6'] = 1
data.loc[data.var_6 <= data.var_6.median() ,'var_6'] = 0

data.loc[data.var_22 > data.var_22.median() ,'var_22'] = 1
data.loc[data.var_22 <= data.var_22.median() ,'var_22'] = 0

data.loc[data.var_26 > data.var_26.median() ,'var_26'] = 1
data.loc[data.var_26 <= data.var_26.median() ,'var_26'] = 0

data.loc[data.var_99 > data.var_99.median() ,'var_99'] = 1
data.loc[data.var_99 <= data.var_99.median() ,'var_99'] = 0

data.loc[data.var_110 > data.var_110.median() ,'var_110'] = 1
data.loc[data.var_110 <= data.var_110.median() ,'var_110'] = 0

data.loc[data.var_12 > data.var_12.median() ,'var_12'] = 1
data.loc[data.var_12 <= data.var_12.median() ,'var_12'] = 0

data.loc[data.var_76 > data.var_76.median() ,'var_76'] = 1
data.loc[data.var_76 <= data.var_76.median() ,'var_76'] = 0

data.loc[data.var_146 > data.var_146.median() ,'var_146'] = 1
data.loc[data.var_146 <= data.var_146.median() ,'var_146'] = 0

data.loc[data.var_148 > data.var_148.median() ,'var_148'] = 1
data.loc[data.var_148 <= data.var_148.median() ,'var_148'] = 0

data.loc[data.var_166 > data.var_166.median() ,'var_166'] = 1
data.loc[data.var_166 <= data.var_166.median() ,'var_166'] = 0
'''
# Out:
# "data.loc[data.var_6 > data.var_6.median() ,'var_6'] = 1\ndata.loc[data.var_6 <= data.var_6.median() ,'var_6'] = 0\n\ndata.loc[data.var_22 > data.var_22.median() ,'var_22'] = 1\ndata.loc[data.var_22 <= data.var_22.median() ,'var_22'] = 0\n\ndata.loc[data.var_26 > data.var_26.median() ,'var_26'] = 1\ndata.loc[data.var_26 <= data.var_26.median() ,'var_26'] = 0\n\ndata.loc[data.var_99 > data.var_99.median() ,'var_99'] = 1\ndata.loc[data.var_99 <= data.var_99.median() ,'var_99'] = 0\n\ndata.loc[data.var_110 > data.var_110.median() ,'var_110'] = 1\ndata.loc[data.var_110 <= data.var_110.median() ,'var_110'] = 0\n\ndata.loc[data.var_12 > data.var_12.median() ,'var_12'] = 1\ndata.loc[data.var_12 <= data.var_12.median() ,'var_12'] = 0\n\ndata.loc[data.var_76 > data.var_76.median() ,'var_76'] = 1\ndata.loc[data.var_76 <= data.var_76.median() ,'var_76'] = 0\n\ndata.loc[data.var_146 > data.var_146.median() ,'var_146'] = 1\ndata.loc[data.var_146 <= data.var_146.median() ,'var_146'] = 0\n\ndata.lo
# ...

# %%
data.head(5)
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5  var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834    1.0
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433    0.0
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837    0.0
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361    0.0
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486    0.0
#
#      var_7   var_8   var_9  var_10   var_11   var_12   var_13  var_14  \
# 0  18.6266 -4.9200  5.7470  2.9252   3.1821  14.0137   0.5745  8.7989
# 1  16.5338  3.1468  8.0851 -0.4032   8.0585  14.0239   8.4135  5.4345
# 2  14.6155 -4.9193  5.9525 -0.3249 -11.2648   0.0000   7.3124  7.5244
# 3  14.9250 -5.8609  8.2450  2.3061   2.8102  13.8463  11.9704  6.4569
# 4  19.2514  6.2654  7.6784 -9.4458 -12.1419  13.8481   7.8895  7.7894
#
#     var_15   var_16   var_17   var_18   var_19   var_20   var_21  var_22  \
# ...

# %%
#from sklearn.utils import shuffle
#data['feat1']=data.var_6*data.var_22*data.var_99*data.var_110*data.var_26
#data['feat2']=data.var_12*data.var_76*data.var_146*data.var_148*data.var_166

#data=shuffle(data,random_state=42)

# %%
# Out:
#            target     var_0     var_1     var_2     var_3     var_4     var_5  \
# target   1.000000  0.052390  0.050343  0.055870  0.011055  0.010915  0.030979
# var_0    0.052390  1.000000 -0.000544  0.006573  0.003801  0.001326  0.003046
# var_1    0.050343 -0.000544  1.000000  0.003980  0.000010  0.000303 -0.000902
# var_2    0.055870  0.006573  0.003980  1.000000  0.001001  0.000723  0.001569
# var_3    0.011055  0.003801  0.000010  0.001001  1.000000 -0.000322  0.003253
# var_4    0.010915  0.001326  0.000303  0.000723 -0.000322  1.000000 -0.001368
# var_5    0.030979  0.003046 -0.000902  0.001569  0.003253 -0.001368  1.000000
# var_6    0.066731  0.006983  0.003258  0.000883 -0.000774  0.000049  0.002588
# var_7   -0.003025  0.002429  0.001511 -0.000991  0.002500  0.004549 -0.000995
# var_8    0.019584  0.004962  0.004098  0.002648  0.003553  0.001194  0.000147
# var_9   -0.042805 -0.002613 -0.000832 -0.001932 -0.000826 -0.000918 -0.005279
# ...

# %%
#data.loc[data.target1 <= 0.5, 'target'] = data.target1*1.3
#data.loc[data.target1 > 0.5,

# %%
# Out:
# (11656, 3)

# %%
# Out:
#   ID_code    target
# 0  test_0  0.100702
# 1  test_1  0.313403
# 2  test_2  0.258088
# 3  test_3  0.276896
# 4  test_4  0.064605

# %%
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

plt.grid
sns.distplot(data.var_185,bins=500)

# %%
sns.pairplot(data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-9f33636b51d6> in <module>
# ----> 1 sns.pairplot(data)
#
# c:\program files\python36\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2082                     hue_order=hue_order, palette=palette,
#    2083                     diag_sharey=diag_sharey,
# -> 2084                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2085
#    2086     # Add the markers here as PairGrid has figured out how many levels of the
#
# c:\program files\python36\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, diag_sharey, height, aspect, despine, dropna, size)
# ...

# %%
#data.nunique()
#data.agg('nunique')
plt.scatter(data.var_0, data.var_199)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('var0')
plt.ylabel('var_1')
plt.show()

# %%
import seaborn as sns
sns.boxplot(x=data['var_1'])

# %%
X = data.loc[:, data.columns !='target']
X = X.loc[:, X.columns !='ID_code']
#Q1 = X.quantile(0.25)
#Q3 = X.quantile(0.75)
#IQR = Q3 - Q1

# %%
# Out:
# target      0.000000
# var_0       4.304350
# var_1       6.098650
# var_2       3.794225
# var_3       3.070025
# var_4       2.377950
# var_5      12.125150
# var_6       1.235300
# var_7       5.159100
# var_8       5.255700
# var_9       1.965625
# var_10      7.977875
# var_11      8.363425
# var_12      0.270200
# var_13      7.201975
# var_14      3.488550
# var_15      0.611700
# var_16      3.603625
# var_17      9.665450
# var_18     11.835375
# var_19     12.156825
# var_20      9.251600
# var_21     11.538050
# var_22      4.110800
# var_23      0.769700
# var_24      5.866600
# var_25      0.407300
# var_26      8.231525
# var_27      2.323525
# var_28      1.101600
#              ...
# var_170     6.354900
# var_171     7.677150
# var_172    12.175950
# var_173     8.629425
# var_174    10.576625
# var_175     4.373900
# var_176    11.090900
# var_177     4.122625
# var_178    12.734450
# var_179     3.765550
# var_180     7.670100
# var_181     1.926600
# ...

# %%
key=data[['ID_code','target']]
data= data.loc[:, data.columns !='ID_code']

# %%
data2 = data[~((X> (Q3 + 1.5 * IQR))).any(axis=1)]
data3 = data2[~((X< (Q1 - 1.5* IQR))).any(axis=1)]
# Out:
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
data3.shape
# Out:
# (175104, 202)

# %%
data3.head(2)
# Out:
#    target   var_0   var_1    var_2   var_3    var_4   var_5   var_6    var_7  \
# 0       0  8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187  18.6266
# 2       0  8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427  14.6155
#
#     var_8   ...     var_190  var_191  var_192  var_193  var_194  var_195  \
# 0 -4.9200   ...      4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 2 -4.9193   ...      2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
#
#    var_196  var_197  var_198  var_199
# 0   7.8784   8.5635  12.7803  -1.0914
# 2  -6.5213   8.2675  14.7222   0.3965
#
# [2 rows x 201 columns]

# %%
# Out:
#      var_0    var_1    var_2   var_3    var_4   var_5   var_6    var_7  \
# 0  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493  18.2675
# 1   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196  18.6316
# 2   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950  20.2537
# 3   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397  20.5660
# 4  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595  10.6048
#
#     var_8   var_9  ...   var_191  var_192  var_193  var_194  var_195  var_196  \
# 0  2.1337  8.8100  ...   11.8495  -1.4300   2.4508  13.7112   2.4669   4.3654
# 1 -4.4131  5.9739  ...    8.8349   0.9403  10.1282  15.5765   0.4773  -1.4852
# 2  1.5233  8.3442  ...   10.9935   1.9803   2.1800  12.9813   2.1281  -7.1086
# 3  3.3755  7.4578  ...    9.0766   1.6580   3.5813  15.1874   3.1656   3.9567
# 4  2.9890  7.1437  ...    9.1723   1.2835   3.3778  19.5542  -0.2860  -5.1612
#
#    var_197  var_198  var_199  rank
# ...

# %%
test_0 = test1[~((test1 > (Q3 + 2.4 * IQR))).any(axis=1)]

# %%
t1=t0.iloc[:5000]
t2=t0.iloc[22375:27375]
t3=t0.iloc[49750:54750]
t4=t0.iloc[75125:80125]
t5=t0.iloc[94500:99500]
t6=t0.iloc[116875:121875]
t7=t0.iloc[144250:149250]
t8=t0.iloc[166625:178625]


Data=t1.append(t2)
Data=Data.append(t3)
Data=Data.append(t4)
Data=Data.append(t5)
Data=Data.append(t6)
Data=Data.append(t7)
Data=Data.append(t8)
t9=data[data.target ==1]
Data=Data.append(t9)
#Data=Data.round(2)

# %%
Data.shape
# Out:
# (67098, 202)

# %%
M = data2.loc[:, data2.columns !='target']
M = M.loc[:, M.columns !='ID_code']
#X = X.loc[:, X.columns !=0]
#X=X.iloc[:,0:]
#X.set_index('var_0', inplace=True)

# %%
y = data.loc[:,data.columns == 'target']
y.shape
# Out:
# (200000, 1)

# %%
X = Data.loc[:, Data.columns !=['ID_code','target']]
y = Data.loc[:,Data.columns == 'target']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-da16ff3894a9> in <module>
# ----> 1 X = Data.loc[:, Data.columns !=['ID_code','target']]
#       2 y = Data.loc[:,Data.columns == 'target']
#
# c:\program files\python36\lib\site-packages\pandas\core\indexes\base.py in cmp_method(self, other)
#     102             # don't pass MultiIndex
#     103             with np.errstate(all='ignore'):
# --> 104                 result = ops._comp_method_OBJECT_ARRAY(op, self.values, other)
#     105
#     106         else:
#
# c:\program files\python36\lib\site-packages\pandas\core\ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1118             y = y.values
#    1119
# -> 1120         result = libops.vec_compare(x, y, op)
#    1121     else:
#    1122         result = libops.scalar_compare(x, y, op)
#
# pandas\_libs\ops.pyx in pandas._libs.ops.vec_compare()
#
# ...

# %%
col=['var_7','var_14','var_39','var_124','var_136','var_153','var_10','var_17','var_27','var_30','var_38','var_41','var_96','var_98','var_100','var_103','var_117','var_126','var_158','var_160','var_183','var_185']#,'var_22','var_26','var_99','var_110','var_12','var_76','var_146','var_148','var_166',,'var_6']
X.drop(col,inplace=True,axis=1)

# %%
X=X.round(0)

# %%
import statsmodels.api as sm

logit_model=sm.Logit(y,X)
result=logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.231245
#          Iterations 8
#                          Results: Logit
# ...
# Model:              Logit            Pseudo R-squared: 0.291
# Dependent Variable: target           AIC:              92853.9554
# Date:               2019-03-23 17:15 BIC:              94670.6363
# No. Observations:   200000           Log-Likelihood:   -46249.
# Df Model:           177              LL-Null:          -65232.
# Df Residuals:       199822           LLR p-value:      0.0000
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     8.0000
# ------------------------------------------------------------------
#               Coef.   Std.Err.     z      P>|z|    [0.025   0.975]
# ------------------------------------------------------------------
# var_0         0.0551    0.0028   19.7065  0.0000   0.0496   0.0606
# var_1         0.0406    0.0021   19.0543  0.0000   0.0364   0.0448
# ...

# %%
from imblearn.over_sampling import SMOTE
ros= SMOTE(ratio='auto')
xr, yr = ros.fit_sample(X, y)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-57-812b3080e75b> in <module>
#       1 from imblearn.over_sampling import SMOTE
#       2 ros= SMOTE(ratio='auto')
# ----> 3 xr, yr = ros.fit_sample(X, y)
#
# c:\program files\python36\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      83             self.sampling_strategy, y, self._sampling_type)
#      84
# ---> 85         output = self._fit_resample(X, y)
#      86
#      87         if binarize_y:
#
# c:\program files\python36\lib\site-packages\imblearn\over_sampling\_smote.py in _fit_resample(self, X, y)
#     794     def _fit_resample(self, X, y):
#     795         self._validate_estimator()
# --> 796         return self._sample(X, y)
#     797
#     798     def _sample(self, X, y):
#
# c:\program files\python36\lib\site-packages\imblearn\over_sampling\_smote.py in _sample(self, X, y)
# ...

# %%
from sklearn.feature_extraction.text import TfidfTransformer as tft
import string
from nltk.corpus import stopwords
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)


from collections import Counter
from sklearn.model_selection import train_test_split as tts
from sklearn.model_selection import KFold as kf
from sklearn.model_selection import cross_val_score as cvs
from sklearn.feature_extraction.text import CountVectorizer as cv
from sklearn.feature_extraction.text import TfidfVectorizer as tv
from sklearn.linear_model import LogisticRegression as lr
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.preprocessing import RobustScaler as rs
from sklearn.metrics import classification_report as cr
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier as rfc
from sklearn.ensemble import GradientBoostingClassifier as gbc
from sklearn.kernel_ridge import KernelRidge as kr
from sklearn.metrics import confusion_matrix as cm
from sklearn.metrics import accuracy_score as acc
from sklearn.metrics import f1_score as fs
from sklearn.linear_model import LinearRegression as Lr
from sklearn.pipeline import make_pipeline as mp
from sklearn.naive_bayes import MultinomialNB as mnb
from sklearn.base import BaseEstimator as be
from sklearn.base import TransformerMixin as tm
from sklearn.base import RegressorMixin as rm
from sklearn.base import clone
from nltk.stem import PorterStemmer as ps
from nltk.tokenize import word_tokenize as wt

from sklearn.neighbors import KNeighborsClassifier as knc
from sklearn import model_selection as ms
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB as gn
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as ld
from sklearn.tree import DecisionTreeClassifier as dtc
from sklearn.linear_model import LogisticRegression as lr
from sklearn.model_selection import train_test_split as tts

# %%
xTrain,xTest,yTrain,yTest=tts(X,y,test_size=0.33,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler as ss
scalar=ss()

# %%
xTrainS=scalar.fit(xTrain).fit_transform(xTrain)
xTestS=scalar.fit(xTest).fit_transform(xTest)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import voting_classifier as vC
#model=vC.VotingClassifier(estimators=[lr(verbose=0,penalty='l2',random_state=42),gbc(),rfc(n_estimators=100)],voting='hard')
model=AdaBoostClassifier(algorithm='SAMME.R',n_estimators=300, base_estimator=lr(verbose=0,penalty='l2',random_state=42),learning_rate=0.01,random_state=42)
model.fit(xTrainS,yTrain)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=42, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False),
#           learning_rate=0.01, n_estimators=300, random_state=42)

# %%
# Using Bagging Lets build 100 decision tree models and average/majority vote prediction
from sklearn.ensemble import BaggingClassifier as bc
Bag = bc(base_estimator=lr(C=1.0, class_weight=None, dual=False, penalty='l2', random_state=42), random_state=2017).fit(xTrainS,yTrain)

# %%
results = cvs(Bag, xTrainS, yTrain, cv=5)
print ("\nDecision Tree (Bagging) - Train : ", results.mean())
print ("Decision Tree (Bagging) - Test : ", acc(Bag.predict(xTestS), yTest))

# %%
# Out:
# 5-fold cross validation:

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot as plt

predict=model.predict(xTestS)


# keep probabilities for the positive outcome only
probs = predict#[:, 1]
# calculate AUC
auc = roc_auc_score(yTest, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(yTest, probs)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr)
# show the plot
plt.show()
#predict=[round(value) for value in predict]
#print('Accuracy-score:',acc(yTest,predict[0]))
#print('Confusion-Matrix')
#print(cm(yTest,predict[0]))
#print('Classification Report')
#print(cr(yTest,predict))
#print("f1_score",fs(yTest,predict))
# Out:
# AUC: 0.689

# %%
#------------------------Build LightGBM Model-----------------------
import lightgbm as lgb
train_data=lgb.Dataset(xTrainS,label=yTrain)
valid_data=lgb.Dataset(xTestS,label=yTest)

# %%
#Select Hyper-Parameters
params = {'metric' : 'auc',
#'objective':'binary',
#'boosting_type' : 'gbdt',
'colsample_bytree' : 0.9234,#.9234
'num_leaves' : 3,

'max_depth' : 2,#'xgboost_dart_mode':True,
'n_estimators' : 5635,
'min_child_samples': 399,#399
'min_child_weight': 0.1,
'reg_alpha': 2,
'reg_lambda': 5,
'subsample': 0.855,'verbose' : -1,#.855 .905
'num_threads' : 4
}

alg_conf = {
    'reg_alpha': 2,
    'reg_lambda': 5,
    'verbose' : -1,
    'n_estimators' : 10000,
    "num_boost_round":25,
    'subsample': 0.855,
    "max_depth" : 2,
    "num_leaves" : 3,
    'learning_rate' : 0.1,
    'boosting_type' : 'gbdt',
    'objective' : 'binary',
    "early_stopping_rounds": None,
    }

# %%
param = {
    'n_estimators' : 50000,
    'bagging_freq': 5,
    'bagging_fraction': 0.335,
    #'boost_from_average':'false',
    'boost': 'dart',
    'feature_fraction': 0.041,
    'learning_rate':0.006,# 0.0083,
    'xgboost_dart_mode':True,
    'max_depth': 2,
    'max_bin':1000,
    'metric':'auc',
    'min_data_in_leaf': 80,
    'min_sum_hessian_in_leaf': 10.0,
    'num_leaves': 3,
    'num_threads': 4,
    'tree_learner': 'serial',
    'objective': 'binary', 
    'verbosity': -1
}

# %%
lgbm=lgb.sklearn.LGBMClassifier(num_leaves=alg_conf["num_leaves"], 
                                #n_estimators=alg_conf["num_boost_round"], 
                                max_depth=alg_conf["max_depth"],
                                #max_depth=alg_conf["max_depth"],
                                learning_rate=alg_conf["learning_rate"],
                                objective=alg_conf["objective"],
                                subsample=alg_conf['subsample'],
                                verbose=alg_conf['verbose'],
                                reg_alpha=alg_conf['reg_alpha'],
                                reg_lambda=alg_conf['reg_lambda'],
                                n_estimators=alg_conf['n_estimators'],)
lgbm.fit(xTrainS,yTrain)#,eval_set=(xTestS,yTest))
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=2,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=10000, n_jobs=-1, num_leaves=3, objective='binary',
#         random_state=None, reg_alpha=2, reg_lambda=5, silent=True,
#         subsample=0.855, subsample_for_bin=200000, subsample_freq=0,
#         verbose=-1)

# %%
lgbm.predict_proba(xTestS)
# Out:
# array([[9.99831779e-01, 1.68221389e-04],
#        [9.57274049e-01, 4.27259510e-02],
#        [9.96270684e-01, 3.72931565e-03],
#        ...,
#        [7.98767632e-01, 2.01232368e-01],
#        [9.90057579e-01, 9.94242121e-03],
#        [9.71318840e-01, 2.86811595e-02]])

# %%
#Train model on selected parameters and number of iterations
lgbm = lgb.train(params,
train_data,
2500,
valid_sets=valid_data,
#early_stopping_rounds= 500,
verbose_eval= 5
)
# Out:
# [5]	valid_0's auc: 0.642246
# [10]	valid_0's auc: 0.687212
# [15]	valid_0's auc: 0.713192
# [20]	valid_0's auc: 0.720197
# [25]	valid_0's auc: 0.731799
# [30]	valid_0's auc: 0.748291
# [35]	valid_0's auc: 0.754793
# [40]	valid_0's auc: 0.756126
# [45]	valid_0's auc: 0.758839
# [50]	valid_0's auc: 0.761041
# [55]	valid_0's auc: 0.765856
# [60]	valid_0's auc: 0.770301
# [65]	valid_0's auc: 0.77454
# [70]	valid_0's auc: 0.776036
# [75]	valid_0's auc: 0.777519
# [80]	valid_0's auc: 0.779806
# [85]	valid_0's auc: 0.781334
# [90]	valid_0's auc: 0.783109
# [95]	valid_0's auc: 0.780665
# [100]	valid_0's auc: 0.782242
# [105]	valid_0's auc: 0.782651
# [110]	valid_0's auc: 0.782908
# [115]	valid_0's auc: 0.78936
# [120]	valid_0's auc: 0.791513
# [125]	valid_0's auc: 0.789848
# [130]	valid_0's auc: 0.791526
# [135]	valid_0's auc: 0.791197
# [140]	valid_0's auc: 0.791766
# [145]	valid_0's auc: 0.793056
# [150]	valid_0's auc: 0.793485
# [155]	valid_0's auc: 0.793352
# ...

# %% [markdown]
# from catboost import Pool, CatBoostClassifier, cv
# from sklearn.model_selection import GridSearchCV

# %%
import numpy as np
cate_features = np.array(X.var_68).astype(int)

# %%
from catboost import Pool, CatBoostClassifier

# %%
#let us make the catboost model, use_best_model params will make the model prevent overfitting
param={'l2_leaf_reg':[ 2],
    #bagging_temperature=1,
    #random_strength=3,
    #one_hot_max_size=2,
                           
    'boosting_type':['Plain'],
    'iterations':[9865],
    'depth':[2],
    'learning_rate':[0.055],
    'loss_function':['Logloss','CrossEntropy'],
    'logging_level':['Verbose'],
    'eval_metric':['AUC'],
    'use_best_model':['True'],
    'random_seed':[42]}
#model = CatBoostClassifier()
#CatBoostClassifier(l2_leaf_reg= 2,iterations=10000, depth=2,learning_rate=0.055, loss_function='Logloss',logging_level='Verbose', eval_metric='AUC',use_best_model=True,random_seed=42)
model = CatBoostClassifier(l2_leaf_reg= 2,
                           #bagging_temperature=1,
                           #random_strength=3,
                           #one_hot_max_size=2,
                           
                           boosting_type='Plain',
                           iterations=9865, 
                           depth=2,
                           learning_rate=0.055,
                           loss_function='Logloss',
                           logging_level='Verbose',
                           eval_metric='AUC',
                           use_best_model=True,
                           random_seed=42)
model.fit(xTrainS,yTrain,eval_set=(xTestS,yTest))
#model = GridSearchCV(model,param, scoring="roc_auc", cv = 3)
# Out:
# 0:	test: 0.5638770	best: 0.5638770 (0)	total: 406ms	remaining: 1h 6m 43s
# 1:	test: 0.5764374	best: 0.5764374 (1)	total: 576ms	remaining: 47m 20s
# 2:	test: 0.5832084	best: 0.5832084 (2)	total: 833ms	remaining: 45m 36s
# 3:	test: 0.6149148	best: 0.6149148 (3)	total: 1.01s	remaining: 41m 36s
# 4:	test: 0.6234964	best: 0.6234964 (4)	total: 1.25s	remaining: 41m 14s
# 5:	test: 0.6272193	best: 0.6272193 (5)	total: 1.46s	remaining: 40m 1s
# 6:	test: 0.6329065	best: 0.6329065 (6)	total: 1.73s	remaining: 40m 30s
# 7:	test: 0.6337283	best: 0.6337283 (7)	total: 1.92s	remaining: 39m 27s
# 8:	test: 0.6392895	best: 0.6392895 (8)	total: 2.16s	remaining: 39m 21s
# 9:	test: 0.6557060	best: 0.6557060 (9)	total: 2.33s	remaining: 38m 19s
# 10:	test: 0.6644728	best: 0.6644728 (10)	total: 2.6s	remaining: 38m 45s
# 11:	test: 0.6743554	best: 0.6743554 (11)	total: 2.77s	remaining: 37m 54s
# 12:	test: 0.6862727	best: 0.6862727 (12)	total: 3.02s	remaining: 38m 4s
# ...

# %%
test=pd.read_csv('test.csv')
test1 = test.loc[:, test.columns !='ID_code']
#test.drop('ID_code',axis=1,inplace=True)
test1.drop(col,inplace=True,axis=1)

# %%
trainS=scalar.fit(X).fit_transform(X)
testS=scalar.fit(test1).fit_transform(test1)

# %%
model = CatBoostClassifier(l2_leaf_reg= 2,
                           #bagging_temperature=3,
                           #random_strength=3,
                           #one_hot_max_size=2,
                           
                           boosting_type='Plain',
                           iterations=9826,
                           depth=2,
                           learning_rate=0.055,
                           loss_function='Logloss',
                           logging_level='Verbose',
                           eval_metric='AUC',
                           #use_best_model=True,
                           random_seed=42)
model.fit(trainS,y)
# Out:
# 0:	total: 1.95s	remaining: 5h 18m 42s
# 1:	total: 2.51s	remaining: 3h 25m 44s
# 2:	total: 2.84s	remaining: 2h 34m 57s
# 3:	total: 3.11s	remaining: 2h 7m 22s
# 4:	total: 3.48s	remaining: 1h 54m 3s
# 5:	total: 3.73s	remaining: 1h 41m 41s
# 6:	total: 4.05s	remaining: 1h 34m 42s
# 7:	total: 4.34s	remaining: 1h 28m 41s
# 8:	total: 4.58s	remaining: 1h 23m 11s
# 9:	total: 4.84s	remaining: 1h 19m 16s
# 10:	total: 5.08s	remaining: 1h 15m 36s
# 11:	total: 5.42s	remaining: 1h 13m 56s
# 12:	total: 5.88s	remaining: 1h 13m 56s
# 13:	total: 6.14s	remaining: 1h 11m 44s
# 14:	total: 6.35s	remaining: 1h 9m 11s
# 15:	total: 6.56s	remaining: 1h 7m 4s
# 16:	total: 6.78s	remaining: 1h 5m 10s
# 17:	total: 7.05s	remaining: 1h 4m 1s
# 18:	total: 7.35s	remaining: 1h 3m 14s
# 19:	total: 7.63s	remaining: 1h 2m 21s
# 20:	total: 7.93s	remaining: 1h 1m 44s
# 21:	total: 8.17s	remaining: 1h 40s
# 22:	total: 8.47s	remaining: 1h 10s
# 23:	total: 8.75s	remaining: 59m 32s
# 24:	total: 9.01s	remaining: 58m 50s
# ...

# %%
predictions=model.predict(testS)

# %%
predictions = predictions[:, 1]

# %%
# calculate AUC
auc = roc_auc_score(yTest, predictions)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(yTest, probs)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
# show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-31b07dccdc82> in <module>
#       1
#       2 # calculate AUC
# ----> 3 auc = roc_auc_score(yTest, predictions)
#       4 print('AUC: %.3f' % auc)
#       5 # calculate roc curve
#
# NameError: name 'roc_auc_score' is not defined

# %%
test2=pd.read_csv('test.csv')

# %%
final=pd.DataFrame({'ID_code':test['ID_code'],'target':predictions})
final.to_csv('final2.csv',index=False)

# %%
test3=pd.read_csv('customresult3.csv')
#t=test3[test3.target ==1]
test3.head()
# Out:
#   ID_code    target
# 0  test_0  0.455660
# 1  test_1  0.459348
# 2  test_2  0.431060
# 3  test_3  0.455841
# 4  test_4  0.433994

# %%
#0    147378  142774   144430  143375
#1     52622    57226  55570    56625
